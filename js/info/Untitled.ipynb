# %%
import pandas as pd

# %%
# Out:
#        Symbol        Name  Market
# 0     A005930        삼성전자   KOSPI
# 1     A000660      SK하이닉스   KOSPI
# 2     A068270        셀트리온   KOSPI
# 3     A005380         현대차   KOSPI
# 4     A005490       POSCO   KOSPI
# 5     A207940    삼성바이오로직스   KOSPI
# 6     A028260        삼성물산   KOSPI
# 7     A051910        LG화학   KOSPI
# 8     A105560        KB금융   KOSPI
# 9     A015760        한국전력   KOSPI
# 10    A032830        삼성생명   KOSPI
# 11    A035420       NAVER   KOSPI
# 12    A012330       현대모비스   KOSPI
# 13    A055550        신한지주   KOSPI
# 14    A051900      LG생활건강   KOSPI
# 15    A034730          SK   KOSPI
# 16    A090430      아모레퍼시픽   KOSPI
# 17    A096770     SK이노베이션   KOSPI
# 18    A017670       SK텔레콤   KOSPI
# 19    A018260     삼성에스디에스   KOSPI
# 20    A066570        LG전자   KOSPI
# 21    A006400       삼성SDI   KOSPI
# 22    A251270         넷마블   KOSPI
# 23    A033780        KT&G   KOSPI
# 24    A000270         기아차   KOSPI
# 25    A003550          LG   KOSPI
# ...
